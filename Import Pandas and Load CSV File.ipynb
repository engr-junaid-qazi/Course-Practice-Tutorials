# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
ch.head()
#print(ch.head())
# Out:
#   TOTAL VACANT SEATS - GULZAR-E-HIJRI, GULSHAN TOWN, GULSHAN-E-IQBAL - MALE - 52-POSTS  \
# 0                                                SR#
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#   Unnamed: 1          Unnamed: 2            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    SEAT_NO      CANDIDATE NAME   FATHER/HUSBAND NAME     GENDER   RELIGION
# 1   11790077          ALI JAWWAD    SYED MASOOD AKHTAR       Male     Muslim
# 2   11820986  MUHAMMAD QAVI KHAN        MUHAMMAD RAEES       Male     Muslim
# 3   11810161      MUHAMMAD TAHIR  SHAIKH MUHAMMAD ABID       Male     Muslim
# 4   11820048   MIRZA NABEEL BAIG     MIRZA YOUNUS BAIG       Male     Muslim
#
#    Unnamed: 6 Unnamed: 7    Unnamed: 8       Unnamed: 9     Unnamed: 10
# 0  DISABILITY     REGION      DISTRICT           TEHSIL  MARKS_OBTAINED
# ...

# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
ch
#print(ch.head())
# Out:
#    TOTAL VACANT SEATS - GULZAR-E-HIJRI, GULSHAN TOWN, GULSHAN-E-IQBAL - MALE - 52-POSTS  \
# 0                                                 SR#
# 1                                                   1
# 2                                                   2
# 3                                                   3
# 4                                                   4
# ..                                                ...
# 73                                                  1
# 74                                                  2
# 75                                                  3
# 76                                                  4
# 77                                                  5
#
#    Unnamed: 1          Unnamed: 2            Unnamed: 3 Unnamed: 4  \
# 0     SEAT_NO      CANDIDATE NAME   FATHER/HUSBAND NAME     GENDER
# 1    11790077          ALI JAWWAD    SYED MASOOD AKHTAR       Male
# 2    11820986  MUHAMMAD QAVI KHAN        MUHAMMAD RAEES       Male
# ...

# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
name = ch['Unnamed: 2']
print(name)
# Out:
# 0         CANDIDATE NAME
# 1             ALI JAWWAD
# 2     MUHAMMAD QAVI KHAN
# 3         MUHAMMAD TAHIR
# 4      MIRZA NABEEL BAIG
#              ...
# 73        KRISHNA MOORTI
# 74        NARENDAR KUMAR
# 75      SHAROON SHAMSHAD
# 76           VIJAY KUMAR
# 77        SHAHZAIB EDGAR
# Name: Unnamed: 2, Length: 78, dtype: object

# %%
question = 12*8
solution = 96
question == solution
# Out:
# True

# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
name = ch['Unnamed: 2']
print(name.head())
# Out:
# 0        CANDIDATE NAME
# 1            ALI JAWWAD
# 2    MUHAMMAD QAVI KHAN
# 3        MUHAMMAD TAHIR
# 4     MIRZA NABEEL BAIG
# Name: Unnamed: 2, dtype: object

# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
name = (ch['Unnamed: 2'], ch['Unnamed: 10'])
print(name)
# Out:
# (0         CANDIDATE NAME
# 1             ALI JAWWAD
# 2     MUHAMMAD QAVI KHAN
# 3         MUHAMMAD TAHIR
# 4      MIRZA NABEEL BAIG
#              ...
# 73        KRISHNA MOORTI
# 74        NARENDAR KUMAR
# 75      SHAROON SHAMSHAD
# 76           VIJAY KUMAR
# 77        SHAHZAIB EDGAR
# Name: Unnamed: 2, Length: 78, dtype: object, 0     MARKS_OBTAINED
# 1                 72
# 2                 67
# 3                 67
# 4                 66
#            ...
# 73                60
# 74                57
# 75                54
# 76                49
# 77                46
# Name: Unnamed: 10, Length: 78, dtype: object)

# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
name = (ch['Unnamed: 2'], ch['Unnamed: 10'])
#name.head()
print(ch.head())
# Out:
#   TOTAL VACANT SEATS - GULZAR-E-HIJRI, GULSHAN TOWN, GULSHAN-E-IQBAL - MALE - 52-POSTS  \
# 0                                                SR#
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#   Unnamed: 1          Unnamed: 2            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    SEAT_NO      CANDIDATE NAME   FATHER/HUSBAND NAME     GENDER   RELIGION
# 1   11790077          ALI JAWWAD    SYED MASOOD AKHTAR       Male     Muslim
# 2   11820986  MUHAMMAD QAVI KHAN        MUHAMMAD RAEES       Male     Muslim
# 3   11810161      MUHAMMAD TAHIR  SHAIKH MUHAMMAD ABID       Male     Muslim
# 4   11820048   MIRZA NABEEL BAIG     MIRZA YOUNUS BAIG       Male     Muslim
#
#    Unnamed: 6 Unnamed: 7    Unnamed: 8       Unnamed: 9     Unnamed: 10
# 0  DISABILITY     REGION      DISTRICT           TEHSIL  MARKS_OBTAINED
# ...

# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
name = (ch['Unnamed: 2'], ch['Unnamed: 10'])
#name.head()
print(name)
# Out:
# (0         CANDIDATE NAME
# 1             ALI JAWWAD
# 2     MUHAMMAD QAVI KHAN
# 3         MUHAMMAD TAHIR
# 4      MIRZA NABEEL BAIG
#              ...
# 73        KRISHNA MOORTI
# 74        NARENDAR KUMAR
# 75      SHAROON SHAMSHAD
# 76           VIJAY KUMAR
# 77        SHAHZAIB EDGAR
# Name: Unnamed: 2, Length: 78, dtype: object, 0     MARKS_OBTAINED
# 1                 72
# 2                 67
# 3                 67
# 4                 66
#            ...
# 73                60
# 74                57
# 75                54
# 76                49
# 77                46
# Name: Unnamed: 10, Length: 78, dtype: object)

# %%
import pandas as pd
ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
name = ch[ch['Unnamed: 10'] > '60']
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-a35be563b565> in <module>
#       1 import pandas as pd
#       2 ch = pd.read_excel(r'D:\JOBS & SCHOLARSHIPS\PST JEST JOB\LISTS\Gulshan Town Male.xlsx')
# ----> 3 name = ch[ch['Unnamed: 10'] > '60']
#       4 print(name)
#
# C:\Users\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# C:\Users\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ...

# %%
import pandas as pd 
ch = pd.read_excel(r'H:\AI - SAYLANI COURSE - DATASETS\2.Merit List - Artificial Intelligence (Robotics).xlsx')
ch
# Out:
#     Unnamed: 0 Candidate Code                        Name  \
# 0            1    CND-0020014  Sheikh Muhammad Tabish Ali
# 1            2   CND-00289826          Adnan Ali Khan Zai
# 2            3    CND-0054628                  Abdul bari
# 3            4     CND-007700                      M. Ali
# 4            5   CND-00109133         Faheem Abdul Raheem
# 5            6   CND-00277299                  M. Mubeen
# 6            7    CND-0079382          Junaid Ahmed Dahri
# 7            8    CND-0080171           M. Wajahat Ghauri
# 8            9    CND-0084996              M. Ammar Umer
# 9           10   CND-00132394                Norbin Rohan
# 10          11    CND-0029076    Syeda Dania Batool Abidi
# 11          12    CND-0079781           Faiza Zehra Agha
# 12          13    CND-0020583            Najeeb ur Rehman
# 13          14    CND-0065053                     Shahzad
# 14          15   CND-00171325                  Zohaib ali
# ...

# %%
import pandas as pd 
ch = pd.read_excel(r'H:\AI - SAYLANI COURSE - DATASETS\2.Merit List - Artificial Intelligence (Robotics).xlsx')
ch
# Out:
#     S. No. Candidate Code                        Name           Father Name  \
# 0        1    CND-0020014  Sheikh Muhammad Tabish Ali      Sheikh Aslam Ali
# 1        2   CND-00289826          Adnan Ali Khan Zai    Nasir Ali Khan Zai
# 2        3    CND-0054628                  Abdul bari               Shahzad
# 3        4     CND-007700                      M. Ali           M. Alamghir
# 4        5   CND-00109133         Faheem Abdul Raheem          Abdul Raheem
# 5        6   CND-00277299                  M. Mubeen                 Farooq
# 6        7    CND-0079382          Junaid Ahmed Dahri        Khair Muhammad
# 7        8    CND-0080171           M. Wajahat Ghauri        Khadim Hussain
# 8        9    CND-0084996              M. Ammar Umer               M. Umer
# 9       10   CND-00132394                Norbin Rohan         Nadeem Suhail
# 10      11    CND-0029076    Syeda Dania Batool Abidi       Syed Farman Ali
# ...

# %%
ch.describe()
#ch.info()
#ch.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 ch.describe()
#
# NameError: name 'ch' is not defined

# %%
ch.remove("Status")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 ch.remove("Status")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'remove'

# %%
import pandas as pd
ch = pd.read_excel(r'H:\AI - SAYLANI COURSE - DATASETS\2.Merit List - Artificial Intelligence (Robotics).xlsx')
ch
# Out:
#     S. No. Candidate Code                        Name           Father Name  \
# 0        1    CND-0020014  Sheikh Muhammad Tabish Ali      Sheikh Aslam Ali
# 1        2   CND-00289826          Adnan Ali Khan Zai    Nasir Ali Khan Zai
# 2        3    CND-0054628                  Abdul bari               Shahzad
# 3        4     CND-007700                      M. Ali           M. Alamghir
# 4        5   CND-00109133         Faheem Abdul Raheem          Abdul Raheem
# 5        6   CND-00277299                  M. Mubeen                 Farooq
# 6        7    CND-0079382          Junaid Ahmed Dahri        Khair Muhammad
# 7        8    CND-0080171           M. Wajahat Ghauri        Khadim Hussain
# 8        9    CND-0084996              M. Ammar Umer               M. Umer
# 9       10   CND-00132394                Norbin Rohan         Nadeem Suhail
# 10      11    CND-0029076    Syeda Dania Batool Abidi       Syed Farman Ali
# ...

# %%
ch.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 ch.describe()
#
# NameError: name 'ch' is not defined

# %%
import pandas as pd
ch = pd.read_excel(r'H:\AI - SAYLANI COURSE - DATASETS\2.Merit List - Artificial Intelligence (Robotics).xlsx')
ch
# Out:
#     S. No. Candidate Code                        Name           Father Name  \
# 0        1    CND-0020014  Sheikh Muhammad Tabish Ali      Sheikh Aslam Ali
# 1        2   CND-00289826          Adnan Ali Khan Zai    Nasir Ali Khan Zai
# 2        3    CND-0054628                  Abdul bari               Shahzad
# 3        4     CND-007700                      M. Ali           M. Alamghir
# 4        5   CND-00109133         Faheem Abdul Raheem          Abdul Raheem
# 5        6   CND-00277299                  M. Mubeen                 Farooq
# 6        7    CND-0079382          Junaid Ahmed Dahri        Khair Muhammad
# 7        8    CND-0080171           M. Wajahat Ghauri        Khadim Hussain
# 8        9    CND-0084996              M. Ammar Umer               M. Umer
# 9       10   CND-00132394                Norbin Rohan         Nadeem Suhail
# 10      11    CND-0029076    Syeda Dania Batool Abidi       Syed Farman Ali
# ...

# %%
ch.describe()
# Out:
#           S. No.      Cell No.
# count  28.000000  2.800000e+01
# mean   14.500000  3.232655e+09
# std     8.225975  1.380221e+08
# min     1.000000  3.032110e+09
# 25%     7.750000  3.111538e+09
# 50%    14.500000  3.221411e+09
# 75%    21.250000  3.335740e+09
# max    28.000000  3.463233e+09

# %%
ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S. No.          28 non-null     int64
#  1   Candidate Code  28 non-null     object
#  2   Name            28 non-null     object
#  3   Father Name     28 non-null     object
#  4   Status          3 non-null      object
#  5   Cell No.        28 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.4+ KB

# %%
ch.shape
# Out:
# (28, 6)
