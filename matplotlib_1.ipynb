# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Pyplot tutorial

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4, 5, 6], [2, 4, 8, 9, 12, 16])

# %% [markdown]
# ## Formatting the style of your plot

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # plot x and y using red circle markers
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'bo') # plot x and y using blue circle markers
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'r+') # plot x and y using red +markers
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# The **axis** function in the example above takes a list of **[xmin, xmax, ymin, ymax]** and specifies the viewport of the axes.

# %% [markdown]
# If matplotlib were limited to working with lists, it would be fairly useless for numeric processing. Generally, you will use numpy arrays. In fact, all sequences are converted to numpy arrays internally. The example below illustrates plotting several lines with different format styles in one function call using arrays.

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0, 5, 0.3)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
type(data)
# Out:
# dict

# %%
data = {'a': np.arange(100),
        'c': np.random.randint(0, 100, 100),
        'd': np.random.randn(100)}
data['b'] = data['a'] + 10 * np.random.randn(100)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
arr2 = np.arange(2,20,2).reshape(3,3)
arr2
plt.plot(arr2)
#plt.show()
# Out:
# [<matplotlib.lines.Line2D at 0x11eb4b93670>,
#  <matplotlib.lines.Line2D at 0x11eb4b936d0>,
#  <matplotlib.lines.Line2D at 0x11eb4b937f0>]

# %% [markdown]
# # Plotting with categorical variables
#
# It is also possible to create a plot using categorical variables. Matplotlib allows you to pass categorical variables directly to many plotting functions. For example:

# %%
names = ['Cat.-A', 'Cat.-B', 'Cat.-C']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
names = ['Cat.-A', 'Cat.-B', 'Cat.-C', 'Cat.-D']
values = [10, 25, 15, 100]

plt.figure(figsize=(12, 6))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
names = ['Cat.-A', 'Cat.-B', 'Cat.-C', 'Cat.-D']
values = [10, 25, 80, 100]

plt.figure(figsize=(12, 6))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
names = ['Cat.-A', 'Cat.-B', 'Cat.-C', 'Cat.-D']
values = [10, 25, 80, 100]

plt.figure(figsize=(12, 6))

plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)

plt.subplot(129)
plt.hist(names,values)

plt.suptitle('Categorical Plotting')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 15>()
#      12 plt.subplot(133)
#      13 plt.plot(names, values)
# ---> 15 plt.subplot(129)
#      16 plt.hist(names,values)
#      18 plt.suptitle('Categorical Plotting')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:608, in SubplotSpec._from_subplot_args(figure, args)
#     606 else:
#     607     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 608         raise ValueError(
#     609             f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     610     i = j = num
#     611 return gs[i-1:j]
#
# ValueError: num must be 1 <= num <= 2, not 9
